# %%
from deepface import DeepFace
import cv2
import matplotlib.pyplot as plt
import os
# Out:
# 2024-02-16 14:18:51.808266: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
img_path = '/home/KDT-admin/data/images/train/image1.jpg'# 이미지 읽기
img = cv2.imread(img_path)# 이미지 확인
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
detection_models = ['opencv', 'ssd', 'dlib', 'mtcnn', 'retinaface', 'mediapipe']
# 얼굴 검출 및 정렬 진행


face = DeepFace.detectFace(img_path=img_path,
                        detector_backend='mediapipe')
# 얼굴 영역 확인
plt.imshow(cv2.cvtColor(face, cv2.COLOR_BGR2RGB))
# Out:
# 24-02-16 14:20:27 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.

# %%
root_dir = '/home/KDT-admin/data/images'
output_path = '/home/KDT-admin/data/images/cropped'
train_img_list = sorted(os.listdir(os.path.join(root_dir, 'train')))
val_img_list = sorted(os.listdir(os.path.join(root_dir, 'val')))

# %%
input = os.path.join(root_dir, 'train', train_img_list[0])
print(input)
# Out:
# /home/KDT-admin/data/images/train/image0.jpg

# %%
for v in train_img_list:
    input = os.path.join(root_dir, 'train', v)
    img = cv2.imread(input)
    face = DeepFace.detectFace(img_path=img,
                        detector_backend='mediapipe',enforce_detection=False)
    if face is None:
        continue
    plt.imsave(os.path.join(output_path, 'train', v), cv2.cvtColor(face, cv2.COLOR_BGR2RGB))
    #cv2.imwrite(os.path.join(output_path, 'train', v), cv2.cvtColor(face, cv2.COLOR_BGR2RGB))
# Out:
# 24-02-16 14:23:52 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:52 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:52 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:52 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:52 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:52 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:52 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:52 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:52 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:52 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:53 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:53 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:53 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:53 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:53 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:53 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:53 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:53 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:53 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:53 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:53 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:54 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:54 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:54 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:54 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:54 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:54 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:54 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:54 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:54 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:54 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:55 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:55 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:55 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:55 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:55 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:55 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:55 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:55 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:55 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:55 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:56 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:56 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:56 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:56 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:56 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:56 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:56 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:56 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:56 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:57 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:57 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:57 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:57 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:57 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:57 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:57 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:57 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:57 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:58 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:58 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:58 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:58 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:58 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:58 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:58 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:58 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:58 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:59 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:59 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:59 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:59 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:59 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:59 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:59 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:23:59 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:00 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:00 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:00 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:00 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:00 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:00 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:00 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:00 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:00 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:00 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:00 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:01 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:01 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:01 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:01 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:01 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:01 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:01 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:01 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:01 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:02 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:02 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:02 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:02 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:02 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:02 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:02 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:02 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:02 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:02 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:02 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:03 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:03 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:03 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:03 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:03 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:03 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:03 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:03 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:04 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:04 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:04 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:04 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:04 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:04 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:04 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:04 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:04 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:04 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:04 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:05 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:05 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:05 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:05 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:05 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:05 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:05 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:05 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:05 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:05 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:05 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:05 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:06 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:06 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:06 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:06 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:06 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:06 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:06 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:06 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:06 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24
- ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:41 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:41 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:41 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:41 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:42 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:42 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:42 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:42 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:42 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:42 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:42 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:42 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:42 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:42 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:43 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:43 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:43 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:43 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:43 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:43 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:43 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:43 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:43 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:43 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:44 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:44 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:44 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:44 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:44 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:44 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:44 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:44 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:44 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:44 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:45 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:45 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:45 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:45 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:45 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:45 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:45 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:45 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:45 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:45 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:46 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:46 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:46 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:46 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:46 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:46 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:46 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:46 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:46 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:46 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:47 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:47 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:47 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:47 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:47 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:47 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:47 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:47 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:47 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:47 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:48 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:48 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:48 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:48 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:48 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:48 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:48 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:48 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:48 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:48 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:49 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:49 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:49 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:49 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:49 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:49 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:49 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:49 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:50 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:50 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:50 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:50 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:50 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:24:50 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.

# %%
print(len(sorted(os.listdir(os.path.join(root_dir, 'cropped','train')))))
print(len(sorted(os.listdir(os.path.join(root_dir, 'cropped','val')))))
# Out:
# 560
# 140

# %%
for v in val_img_list:
    input = os.path.join(root_dir, 'val', v)
    img = cv2.imread(input)
    face = DeepFace.detectFace(img_path=img,
                        detector_backend='mediapipe',enforce_detection=False)
    if face is None:
        continue
    plt.imsave(os.path.join(output_path, 'val', v), cv2.cvtColor(face, cv2.COLOR_BGR2RGB))
# Out:
# 24-02-16 14:27:43 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:43 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:43 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:43 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:44 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:44 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:44 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:44 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:44 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:44 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:44 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:44 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:44 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:45 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:45 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:45 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:45 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:45 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:45 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:45 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:45 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:45 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:45 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:45 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:46 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:46 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:46 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:46 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:46 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:46 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:46 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:46 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:46 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:47 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:47 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:47 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:47 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:47 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:47 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:47 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:47 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:47 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:48 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:48 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:48 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:48 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:48 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:48 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:48 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:48 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:48 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:48 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:49 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:49 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:49 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:49 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:49 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:49 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:49 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:49 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:49 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:50 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:50 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:50 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:50 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:50 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:50 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:50 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:50 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:50 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:50 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:50 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:51 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:51 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:51 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:51 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:51 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:51 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:51 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:51 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:51 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:52 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:52 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:52 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:52 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:52 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:52 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:52 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:52 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:52 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:52 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:53 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:53 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:53 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:53 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:53 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:53 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:53 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:53 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:53 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:54 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:54 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:54 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:54 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:54 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:54 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:54 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:54 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:54 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:54 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:54 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:55 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:55 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:55 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:55 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:55 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:55 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:55 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:55 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:55 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:56 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:56 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:56 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:56 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:56 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:56 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:56 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:56 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:56 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:56 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:57 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:57 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:57 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:57 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:57 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:57 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:57 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:57 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:57 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-02-16 14:27:57 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.

# %%
detected_face = face

plt.imshow(cv2.cvtColor(detected_face, cv2.COLOR_BGR2RGB))

# %%
# image save
cv2.imwrite("face.jpg", align_face)
